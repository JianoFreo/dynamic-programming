# %%
def sudoku(row,col):
    if col == len(board[row]):
        ## Base case function
    for i in range(9):
        board[row][col] = value
        if validPlacement(row,col):
            if (solve(row,col + 1, borad)):
                return true
