# %%
def lengthOfLongestSubstring(string):
        current = 0
        pointer = 1
        print(string[current:pointer])
        print(string[current])
        print(string[pointer])
        
lengthOfLongestSubstring("hello")
# Out:
# h
# h
# e
